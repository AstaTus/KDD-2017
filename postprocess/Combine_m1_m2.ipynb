# %%
import numpy as np
import pandas as pd
import datetime

# %%
m1_df = pd.read_csv('../data/prediction/prediction_m1.csv')

# %%
m1_df = pd.read_csv('../data/prediction/prediction_m1.csv')
m2_df = pd.read_csv('../data/prediction/prediction_m2.csv')

# %%
combine_df = m1_df

# %%
combine_df['avg_travel_time'] = combine_df['avg_travel_time'] + m2_df['avg_travel_time']

# %%
m2_df[(m2_df['intersection_id'] == 'C') & (m2_df['tollgate_id'] == 3)]
# Out:
#     intersection_id  tollgate_id                                time_window  \
# 420               C            3  [2016-10-18 08:00:00,2016-10-18 08:20:00)
# 421               C            3  [2016-10-18 08:20:00,2016-10-18 08:40:00)
# 422               C            3  [2016-10-18 08:40:00,2016-10-18 09:00:00)
# 423               C            3  [2016-10-18 09:00:00,2016-10-18 09:20:00)
# 424               C            3  [2016-10-18 09:20:00,2016-10-18 09:40:00)
# 425               C            3  [2016-10-18 09:40:00,2016-10-18 10:00:00)
# 426               C            3  [2016-10-19 08:00:00,2016-10-19 08:20:00)
# 427               C            3  [2016-10-19 08:20:00,2016-10-19 08:40:00)
# 428               C            3  [2016-10-19 08:40:00,2016-10-19 09:00:00)
# 429               C            3  [2016-10-19 09:00:00,2016-10-19 09:20:00)
# 430               C            3  [2016-10-19 09:20:00,2016-10-19 09:40:00)
# ...

# %%
combine_df[(combine_df['intersection_id'] == 'C') & (combine_df['tollgate_id'] == 3)]
# Out:
#     intersection_id  tollgate_id                                time_window  \
# 420               C            3  [2016-10-18 08:00:00,2016-10-18 08:20:00)
# 421               C            3  [2016-10-18 08:20:00,2016-10-18 08:40:00)
# 422               C            3  [2016-10-18 08:40:00,2016-10-18 09:00:00)
# 423               C            3  [2016-10-18 09:00:00,2016-10-18 09:20:00)
# 424               C            3  [2016-10-18 09:20:00,2016-10-18 09:40:00)
# 425               C            3  [2016-10-18 09:40:00,2016-10-18 10:00:00)
# 426               C            3  [2016-10-19 08:00:00,2016-10-19 08:20:00)
# 427               C            3  [2016-10-19 08:20:00,2016-10-19 08:40:00)
# 428               C            3  [2016-10-19 08:40:00,2016-10-19 09:00:00)
# 429               C            3  [2016-10-19 09:00:00,2016-10-19 09:20:00)
# 430               C            3  [2016-10-19 09:20:00,2016-10-19 09:40:00)
# ...

# %%
m1_df[(m1_df['intersection_id'] == 'C') & (m1_df['tollgate_id'] == 3)]
# Out:
#     intersection_id  tollgate_id                                time_window  \
# 420               C            3  [2016-10-18 08:00:00,2016-10-18 08:20:00)
# 421               C            3  [2016-10-18 08:20:00,2016-10-18 08:40:00)
# 422               C            3  [2016-10-18 08:40:00,2016-10-18 09:00:00)
# 423               C            3  [2016-10-18 09:00:00,2016-10-18 09:20:00)
# 424               C            3  [2016-10-18 09:20:00,2016-10-18 09:40:00)
# 425               C            3  [2016-10-18 09:40:00,2016-10-18 10:00:00)
# 426               C            3  [2016-10-19 08:00:00,2016-10-19 08:20:00)
# 427               C            3  [2016-10-19 08:20:00,2016-10-19 08:40:00)
# 428               C            3  [2016-10-19 08:40:00,2016-10-19 09:00:00)
# 429               C            3  [2016-10-19 09:00:00,2016-10-19 09:20:00)
# 430               C            3  [2016-10-19 09:20:00,2016-10-19 09:40:00)
# ...

# %%
combine_df.to_csv('../data/prediction/prediction_combine_m1_m2.csv', index=False)
