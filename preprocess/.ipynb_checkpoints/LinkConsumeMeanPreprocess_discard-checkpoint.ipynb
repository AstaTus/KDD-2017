# %%
import numpy as np
import pandas as pd
import datetime

# %%
travel_link_df = pd.read_csv('../data/preprocess/middle_normal_link.csv', parse_dates=['end_time', 'start_time', 'norm_start_time'])

# %%
link_df = pd.read_csv('../data/original/links (table 3).csv', index_col=0)

# %%
am_start_date = pd.to_datetime('2016-07-19')
am_end_date = pd.to_datetime('2016-10-17')

morning_link_consume_dict = {}
afternoon_link_consume_dict = {}

for link_id in link_df.index.values:
    appoint_link_df = travel_link_df[travel_link_df['link'] == link_id]
    morning_link_consumes = []
    afternoon_link_consumes = []
    for t in range(12):
        norm_date = am_start_date

        day_morning_consumes = []
        day_afternoon_consumes = []
        
        while (norm_date <= am_end_date ):
            morning_time = norm_date + datetime.timedelta(hours=6, minutes=20 * t)
            afternoon_time = norm_date + datetime.timedelta(hours=15, minutes=20 * t)

            temp_df = appoint_link_df[appoint_link_df['norm_start_time'] == morning_time]
            day_morning_consumes.extend(temp_df['consume'])

            temp_df = appoint_link_df[appoint_link_df['norm_start_time'] == afternoon_time]
            day_afternoon_consumes.extend(temp_df['consume'])

            norm_date = norm_date + datetime.timedelta(days=1)
            
        morning_link_consumes.append(np.mean(day_morning_consumes))
        afternoon_link_consumes.append(np.mean(day_afternoon_consumes))
    morning_link_consume_dict[link_id] = morning_link_consumes
    afternoon_link_consume_dict[link_id] = afternoon_link_consumes

# %%
pd.DataFrame(morning_link_consume_dict).T.to_csv('../data/preprocess/morning_middle_link_mean_consume.csv')
pd.DataFrame(afternoon_link_consume_dict).T.to_csv('../data/preprocess/afternoon_middle_link_mean_consume.csv')

# %%
pd.DataFrame(morning_link_consume_dict).T
# Out:
#             0          1          2          3          4          5   \
# 100   5.632937   5.516452   6.254422   6.367732   6.017871   5.956254
# 101   7.250412   6.980439   7.918205   7.627066   7.718122   7.647714
# 102   8.779400   8.994458   9.280738   9.380937   9.576364   9.391988
# 103   2.761429   3.005533   2.890116   3.016406   2.658730   2.916584
# 104  19.852909  19.932405  20.872564  21.799394  23.550588  23.210784
# 105   8.451333   8.598500   9.758822   9.371149   8.727566   9.169393
# 106   1.424062   1.506577   1.600115   1.516296   1.521330   1.487838
# 107   3.124267   3.360241   3.302541   3.727482   4.220888   4.398130
# 108   3.971450   4.278905   4.237692   4.781281   5.109518   5.060444
# 109   8.397966   8.500875   8.865294   9.209018   9.367009   9.215283
# 110  10.216119  10.386571  10.485171  10.997572  11.074117  11.122810
# 111  14.253350  15.327752  16.142087  20.023723  20.530217  21.483566
